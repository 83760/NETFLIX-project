# %%
# !pip install gdown

# %%
# !pip install pandas

# %%
#Tmporting Libraries

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
#Loading Dataset

# %%
netflix = pd.read_csv("\\Users\\Admin\\Desktop\\Python\\netflix.csv")

# %%
#Data Exploration

# %%
#The first 10 rows of the dataset

# %%
netflix.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
#Shape of the dataset

# %%
netflix.shape
# Out:
# (8807, 12)

# %%
#INSIGHTS :- Based on the output obtained, it can be seen that the dataset consists of 8807 rows and 12 columns.

# %%
#Columns of the dataset

# %%
netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#INSIGHTS :- The dataset has 13 columns consisting of show_id, title, description, director, genres, cast, 
#country, release_year, duration, type, date_added, rating.

# %%
#Information of the dataset

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
#INSIGHTS :- Based on the output obtained, it can be seen that the majority of columns have a total of 8807 non-null values,
#but there are 6 columns that have a varying number of non-null values. In addition, it can be seen that 11 columns have
#an object data type and 1 column has a integer data type.

# %%
#Number of null values per column

# %%
netflix.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
#INSIGHTS :- From the output above, we know that there are 6 columns with null values. ‘director’ column has 2634 null 
#values, ‘cast’ has 825 null values, ‘country’ has 831 null values, ‘rating’ has 4 null values, ‘duration’ has 3 null values,
#and ‘date_added’ has 10 null values.

# %%
#Number of unique values per column

# %%
netflix.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %%
#INSIGHTS :- From the above output, we know that numerically unique count of values from all the columns are shown.

# %%
#Data Cleansing

# %%
#Copy of the dataset

# %%
flix = netflix.copy()

# %%
flix.shape
# Out:
# (8807, 12)

# %%
#Imputing missing values

# %%
flix.cast.fillna("cast_NA", inplace=True)
flix.country.fillna("country_NA", inplace=True)
flix.director.fillna("director_NA", inplace=True)

# %%
#Dropping missing values

# %%
flix.dropna(subset=["date_added", "rating", "duration"], inplace=True)

# %%
#Dataset information after cleaning the data

# %%
flix.shape
# Out:
# (8790, 12)

# %%
#INSIGHTS :- Based on the output obtained, after imputing and cleaning data it can be seen that the dataset consists of 
#8790 rows and 12 columns.

# %%
flix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8790 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   cast          8790 non-null   object
#  5   country       8790 non-null   object
#  6   date_added    8790 non-null   object
#  7   release_year  8790 non-null   int64
#  8   rating        8790 non-null   object
#  9   duration      8790 non-null   object
#  10  listed_in     8790 non-null   object
#  11  description   8790 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 892.7+ KB

# %%
flix.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water      director_NA
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                            cast_NA  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...     country_NA
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
flix['type'].value_counts(normalize=True)*100
# Out:
# Movie      69.692833
# TV Show    30.307167
# Name: type, dtype: float64

# %%
#INSIGHTS :- Based on the output obtained, dataset consist approximately 70% of 'Movies' and 30% of 'TV shows'.

# %%
flix['rating'].value_counts()
# Out:
# TV-MA       3205
# TV-14       2157
# TV-PG        861
# R            799
# PG-13        490
# TV-Y7        333
# TV-Y         306
# PG           287
# TV-G         220
# NR            79
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: rating, dtype: int64

# %%
#INSIGHTS :- Based on above data obtained, TV-MA is the 'rating' with maximum number of i.e. 3205 'title' available in 
#dataset.

# %%
flix['release_year'].value_counts().sort_index()
# Out:
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       4
#         ...
# 2017    1030
# 2018    1146
# 2019    1030
# 2020     953
# 2021     592
# Name: release_year, Length: 74, dtype: int64

# %%
flix['duration'].value_counts()
# Out:
# 1 Season     1791
# 2 Seasons     421
# 3 Seasons     198
# 90 min        152
# 94 min        146
#              ...
# 16 min          1
# 186 min         1
# 193 min         1
# 189 min         1
# 191 min         1
# Name: duration, Length: 220, dtype: int64

# %%
#Approach for Pre-processing

# %%
df1 = flix['cast'].apply(lambda x: str(x).split(', ')).tolist()

# %%
df1=pd.DataFrame(df1,index=flix['title'])

df1=df1.stack()

df1=pd.DataFrame(df1)


df1.reset_index(inplace=True)

df1=df1[['title',0]]

df1.columns=['title','cast']

df1[df1['cast']=='Rupa Bhimani']
# Out:
#                                                    title          cast
# 313                                         Chhota Bheem  Rupa Bhimani
# 708                                          Mighty Raju  Rupa Bhimani
# 3373                       Chhota Bheem - Dinosaur World  Rupa Bhimani
# 3379                        Chhota Bheem - Neeli Pahaadi  Rupa Bhimani
# 3386                               Chhota Bheem & Ganesh  Rupa Bhimani
# 3393                  Chhota Bheem & Krishna: Mayanagari  Rupa Bhimani
# 3400   Chhota Bheem & Krishna: Pataliputra- City of t...  Rupa Bhimani
# 3407                  Chhota Bheem And The Broken Amulet  Rupa Bhimani
# 3414              Chhota Bheem And The Crown of Valhalla  Rupa Bhimani
# 3421                Chhota Bheem and the Incan Adventure  Rupa Bhimani
# 3428                 Chhota Bheem and The ShiNobi Secret  Rupa Bhimani
# 3435                            Chhota Bheem Aur Hanuman  Rupa Bhimani
# ...

# %%
df1
# Out:
#                       title                   cast
# 0      Dick Johnson Is Dead                cast_NA
# 1             Blood & Water             Ama Qamata
# 2             Blood & Water            Khosi Ngema
# 3             Blood & Water          Gail Mabalane
# 4             Blood & Water         Thabang Molaba
# ...                     ...                    ...
# 64836                Zubaan       Manish Chaudhary
# 64837                Zubaan           Meghna Malik
# 64838                Zubaan          Malkeet Rauni
# 64839                Zubaan         Anita Shabdish
# 64840                Zubaan  Chittaranjan Tripathy
#
# [64841 rows x 2 columns]

# %%
df2 = flix['director'].apply(lambda x: str(x).split(', ')).tolist()

# %%
df2=pd.DataFrame(df2,index=flix['title'])

df2=df2.stack()

df2=pd.DataFrame(df2)


df2.reset_index(inplace=True)

df2=df2[['title',0]]

df2.columns=['title','director']

# %%
df2
# Out:
#                       title         director
# 0      Dick Johnson Is Dead  Kirsten Johnson
# 1             Blood & Water      director_NA
# 2                 Ganglands  Julien Leclercq
# 3     Jailbirds New Orleans      director_NA
# 4              Kota Factory      director_NA
# ...                     ...              ...
# 9590                 Zodiac    David Fincher
# 9591            Zombie Dumb      director_NA
# 9592             Zombieland  Ruben Fleischer
# 9593                   Zoom     Peter Hewitt
# 9594                 Zubaan      Mozez Singh
#
# [9595 rows x 2 columns]

# %%
df3 = flix['country'].apply(lambda x: str(x).split(', ')).tolist()

# %%
df3=pd.DataFrame(df3,index=flix['title'])

df3=df3.stack()

df3=pd.DataFrame(df3)


df3.reset_index(inplace=True)

df3=df3[['title',0]]

df3.columns=['title','country']

# %%
df3
# Out:
#                        title        country
# 0       Dick Johnson Is Dead  United States
# 1              Blood & Water   South Africa
# 2                  Ganglands     country_NA
# 3      Jailbirds New Orleans     country_NA
# 4               Kota Factory          India
# ...                      ...            ...
# 10823                 Zodiac  United States
# 10824            Zombie Dumb     country_NA
# 10825             Zombieland  United States
# 10826                   Zoom  United States
# 10827                 Zubaan          India
#
# [10828 rows x 2 columns]

# %%
df4 = flix['listed_in'].apply(lambda x: str(x).split(', ')).tolist()

# %%
df4=pd.DataFrame(df4,index=flix['title'])

df4=df4.stack()

df4=pd.DataFrame(df4)


df4.reset_index(inplace=True)

df4=df4[['title',0]]

df4.columns=['title','listed_in']

# %%
df4
# Out:
#                       title                 listed_in
# 0      Dick Johnson Is Dead             Documentaries
# 1             Blood & Water    International TV Shows
# 2             Blood & Water                 TV Dramas
# 3             Blood & Water              TV Mysteries
# 4                 Ganglands            Crime TV Shows
# ...                     ...                       ...
# 19289                  Zoom  Children & Family Movies
# 19290                  Zoom                  Comedies
# 19291                Zubaan                    Dramas
# 19292                Zubaan      International Movies
# 19293                Zubaan          Music & Musicals
#
# [19294 rows x 2 columns]

# %%
dfa = df1.merge(df2, on='title', how='left')

# %%
dfb = df3.merge(df4, on='title', how='left')

# %%
dfx = dfa.merge(dfb, on='title', how='left')

# %%
flix = flix.merge(dfx, on='title', how='left')

# %%
flix.head(10)
# Out:
#   show_id     type                 title       director_x  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water      director_NA
# 2      s2  TV Show         Blood & Water      director_NA
# 3      s2  TV Show         Blood & Water      director_NA
# 4      s2  TV Show         Blood & Water      director_NA
# 5      s2  TV Show         Blood & Water      director_NA
# 6      s2  TV Show         Blood & Water      director_NA
# 7      s2  TV Show         Blood & Water      director_NA
# 8      s2  TV Show         Blood & Water      director_NA
# 9      s2  TV Show         Blood & Water      director_NA
#
#                                               cast_x      country_x  \
# 0                                            cast_NA  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
flix = flix.drop(['cast_x', 'director_x', 'listed_in_x', 'country_x'], axis=1)

# %%
flix = flix.rename(columns={'cast_y': 'cast', 'director_y': 'director', 'listed_in_y': 'listed_in', 'country_y': 'country'})

# %%
flix['date_added'] = pd.to_datetime(flix['date_added'])

flix['date_added'] = flix['date_added'].dt.strftime('%Y-%m-%d')

# %%
flix.head(10)
# Out:
#   show_id     type                 title  date_added  release_year rating  \
# 0      s1    Movie  Dick Johnson Is Dead  2021-09-25          2020  PG-13
# 1      s2  TV Show         Blood & Water  2021-09-24          2021  TV-MA
# 2      s2  TV Show         Blood & Water  2021-09-24          2021  TV-MA
# 3      s2  TV Show         Blood & Water  2021-09-24          2021  TV-MA
# 4      s2  TV Show         Blood & Water  2021-09-24          2021  TV-MA
# 5      s2  TV Show         Blood & Water  2021-09-24          2021  TV-MA
# 6      s2  TV Show         Blood & Water  2021-09-24          2021  TV-MA
# 7      s2  TV Show         Blood & Water  2021-09-24          2021  TV-MA
# 8      s2  TV Show         Blood & Water  2021-09-24          2021  TV-MA
# 9      s2  TV Show         Blood & Water  2021-09-24          2021  TV-MA
#
#     duration                                        description  \
# 0     90 min  As her father nears the end of his life, filmm...
# ...

# %%
#INSIGHTS :- Above dataset is obtained, after pre-processing completion.

# %%
flix['listed_in'].unique()
# Out:
# array(['Documentaries', 'International TV Shows', 'TV Dramas',
#        'TV Mysteries', 'Crime TV Shows', 'TV Action & Adventure',
#        'Docuseries', 'Reality TV', 'Romantic TV Shows', 'TV Comedies',
#        'TV Horror', 'Children & Family Movies', 'Dramas',
#        'Independent Movies', 'International Movies', 'British TV Shows',
#        'Comedies', 'Spanish-Language TV Shows', 'Thrillers',
#        'Romantic Movies', 'Music & Musicals', 'Horror Movies',
#        'Sci-Fi & Fantasy', 'TV Thrillers', "Kids' TV",
#        'Action & Adventure', 'TV Sci-Fi & Fantasy', 'Classic Movies',
#        'Anime Features', 'Sports Movies', 'Anime Series',
#        'Korean TV Shows', 'Science & Nature TV', 'Teen TV Shows',
#        'Cult Movies', 'TV Shows', 'Faith & Spirituality', 'LGBTQ Movies',
#        'Stand-Up Comedy', 'Movies', 'Stand-Up Comedy & Talk Shows',
#        'Classic & Cult TV'], dtype=object)

# %%
flix['listed_in'].nunique()
# Out:
# 42

# %%
flix['listed_in'].value_counts()
# Out:
# Dramas                          29768
# International Movies            28211
# Comedies                        20829
# International TV Shows          12815
# Action & Adventure              12216
# Independent Movies               9834
# Children & Family Movies         9771
# TV Dramas                        8933
# Thrillers                        7107
# Romantic Movies                  6412
# TV Comedies                      4907
# Crime TV Shows                   4715
# Horror Movies                    4571
# Kids' TV                         4555
# Sci-Fi & Fantasy                 4037
# Music & Musicals                 3077
# Romantic TV Shows                3049
# Documentaries                    2407
# TV Action & Adventure            2278
# Anime Series                     2273
# Spanish-Language TV Shows        2118
# British TV Shows                 1799
# Sports Movies                    1531
# Classic Movies                   1434
# TV Mysteries                     1281
# ...

# %%
#INSIGHTS :- From above data, out of 42 genres 'Dramas' are highest with 29768 title content and 28211 title content
#are second highest for 'International Movies'.

# %%
flix['country'].unique()
# Out:
# array(['United States', 'South Africa', 'country_NA', 'India', 'Ghana',
#        'Burkina Faso', 'United Kingdom', 'Germany', 'Ethiopia',
#        'Czech Republic', 'Mexico', 'Turkey', 'Australia', 'France',
#        'Finland', 'China', 'Canada', 'Japan', 'Nigeria', 'Spain',
#        'Belgium', 'South Korea', 'Singapore', 'Italy', 'Romania',
#        'Argentina', 'Venezuela', 'Hong Kong', 'Russia', '', 'Ireland',
#        'Nepal', 'New Zealand', 'Brazil', 'Greece', 'Jordan', 'Colombia',
#        'Switzerland', 'Israel', 'Taiwan', 'Bulgaria', 'Algeria', 'Poland',
#        'Saudi Arabia', 'Thailand', 'Indonesia', 'Egypt', 'Denmark',
#        'Kuwait', 'Netherlands', 'Malaysia', 'Vietnam', 'Hungary',
#        'Sweden', 'Lebanon', 'Syria', 'Philippines', 'Iceland',
#        'United Arab Emirates', 'Norway', 'Qatar', 'Mauritius', 'Austria',
#        'Cameroon', 'Palestine', 'Uruguay', 'United Kingdom,', 'Kenya',
#        'Chile', 'Luxembourg', 'Cambodia', 'Bangladesh', 'Portugal',
# ...

# %%
flix['country'].nunique()
# Out:
# 128

# %%
flix['country'].value_counts().head(10)
# Out:
# United States     59262
# India             22814
# United Kingdom    12918
# country_NA        11894
# Japan              8599
# France             8254
# Canada             7915
# Spain              5315
# South Korea        5043
# Germany            4383
# Name: country, dtype: int64

# %%
#INSIGHTS :- Based on above data obtained, 'United states' is first with 59262 number of content titles and 'India' is
#second with 22814 number of content titles.

# %%
#Maximum title content added year wise

# %%
content_added_count = pd.to_datetime(flix['date_added']).dt.year.value_counts()

# %%
content_added_count
# Out:
# 2019    46970
# 2020    46025
# 2021    36516
# 2018    35770
# 2017    25199
# 2016     8523
# 2015     1560
# 2014      450
# 2011      438
# 2013      207
# 2012       36
# 2009       30
# 2010       20
# 2008       19
# Name: date_added, dtype: int64

# %%
#INSIGHTS :- Based on above data obtained, In 2019 and 2020 are the years when maximum number of title contents are added
#in netflix platform.

# %%
Cast_count = flix['cast'].value_counts().head(10)

# %%
Cast_count
# Out:
# cast_NA             2146
# Liam Neeson          161
# Alfred Molina        160
# John Krasinski       139
# Salma Hayek          130
# Frank Langella       128
# Anupam Kher          127
# John Rhys-Davies     125
# Shah Rukh Khan       108
# Naseeruddin Shah     106
# Name: cast, dtype: int64

# %%
#INSIGHTS :- Above data shows, Liam Neeson and Alfred Molina are the 'cast' acted in maximum number of contents in
#platform.

# %%
director_counts = flix.groupby('director').size().sort_values(ascending=False).head(10)

# %%
director_counts
# Out:
# director
# director_NA            50425
# Martin Scorsese          419
# Youssef Chahine          409
# Cathy Garcia-Molina      356
# Steven Spielberg         355
# Lars von Trier           336
# Raja Gosnell             308
# Tom Hooper               306
# McG                      293
# David Dhawan             270
# dtype: int64

# %%
#INSIGHTS :- Above data shows, Martin Scorsese and Youssef Chahine are the 'director' directed the maximum number of
#contents in platform.

# %%
#Graphical Analysis

# %%
plt.figure(figsize=(15, 6))
sns.countplot(flix['release_year'])
plt.title('Number of Contents Released per Year', fontsize = 21)
plt.xlabel('release_year')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#INSIGHTS :- Above plot shows,'release_year' 2018 has the maximum number of contents released in this particular year.

# %%
plt.figure(figsize=(16, 8))
sns.countplot(x='release_year', hue='type', data=flix)
plt.title('Number of Movies and TV Shows Released per Year', fontsize = 21)
plt.xlabel('Release Year')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
#INSIGHTS :- Above plot shows,'release_year' 2018 has the maximum number of movies released and 'release_year' 2020
#has the maximum number of tv shows released.

# %%
country_counts = flix.groupby(['country', 'type']).size().unstack(fill_value=0)
fig, ax = plt.subplots(figsize=(20, 8))
country_counts.plot(kind='bar', stacked=True, ax=ax)
plt.title('Content Types by Country', fontsize = 25)
plt.xlabel('Country')
plt.ylabel('Count')
plt.legend(title='Content Type')
plt.xticks(rotation=90)
plt.show()

# %%
#INSIGHTS :- Above plot shows, 'country' united states has released maximum number of movies and tv shows.

# %%
country_percentages = country_counts.div(country_counts.sum(axis=1), axis=0) * 100

# %%
plt.figure(figsize=(14, 14))
sns.heatmap(country_percentages, cmap='Blues', annot=True, fmt='.1f', cbar_kws={'label': 'Percentage'})
plt.title('Percentage of Movies and TV Shows by Country', fontsize = 21)
plt.xlabel('Content Type')
plt.ylabel('Country')
plt.show()

# %%
Countries = flix['country']
Countries = Countries[Countries != 'country_NA']
plt.figure(figsize=(10,8))
g = sns.countplot(x = Countries, order=Countries.value_counts().index[:10], palette='dark:salmon')
plt.title('Top 10 Content Producing Countries', fontsize=21)
plt.xlabel('Country')
plt.ylabel('Titles')
plt.xticks(rotation=45)
plt.show()

# %%
#INSIGHTS :- Above plot shows, 'country' united states and india has released maximum number of contents.

# %%
plt.figure(figsize=(10, 8))
sns.countplot(y='rating', data=flix, order=flix.rating.value_counts().index.to_list(), palette='dark:salmon_r')
plt.title('Number of Content Titles by Rating', fontsize=21);

# %%
#INSIGHTS :- Based on above data obtained, TV-MA is the 'rating' with maximum number of content available in dataset.

# %%
# Calculate the percentage of content types
content_type_percentage = flix['type'].value_counts(normalize=True) * 100

# Plotting the percentage of content types
plt.figure(figsize=(8, 6))
plt.pie(content_type_percentage, labels=content_type_percentage.index, autopct='%1.1f%%', startangle=90)
plt.title('Percentage of Content Types', fontsize = 21)
plt.axis('equal')
plt.show()

# %%
#INSIGHTS :- Based on above data obtained, approximate 72% of content is movie and 28% of content is tv show available
#in platform.

# %%
top_genres = flix['listed_in']
plt.figure(figsize=(10, 6))
sns.countplot(y=top_genres, order=top_genres.value_counts().index.to_list()[:10], palette='Greens_r', saturation=.4)
plt.title('Top 10 Genres with the Largest Number of Content Titles', fontsize=21);

# %%
#INSIGHTS :- Based on above data obtained, Dramas is the genre with the largest number of contents.

# %%
order = ['G', 'TV-Y', 'TV-G', 'PG', 'TV-Y7', 'UR', 'TV-Y7-FV', 'TV-PG', 'PG-13', 'TV-14', 'R', 'NC-17', 'TV-MA', 'NR']
plt.figure(figsize=(15,9))
g = sns.countplot(flix.rating, hue=flix.type, order=order, palette="copper");
plt.title("Ratings for Movies & TV Shows", fontsize=30)
plt.xlabel("Rating")
plt.ylabel("Total Count")
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Filter the movies released in the last 20-30 years
recent_movies = flix[(flix['type'] == 'Movie') & (flix['release_year'] >= 1992) & (flix['release_year'] <= 2022)]

# Group the movies by release year and count the number of movies per year
movies_per_year = recent_movies.groupby('release_year').size()

# Plotting the trend of movies released per year
plt.figure(figsize=(15, 6))
plt.plot(movies_per_year.index, movies_per_year.values, marker='o', linestyle='-', color='b')
plt.title('Number of Movies Released per Year (1992-2021)', fontsize=21)
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.show()

# %%
#INSIGHTS :- Based on above data obtained, sudden raise in trend from 2010 onwards.

# %%
plt.figure(figsize=(14,8))
flix_year = flix['release_year'].value_counts()
flix_year = pd.DataFrame(flix_year).reset_index()
flix_year.columns = ['release_year','title']
sns.barplot(x = 'release_year',y = 'title', data=flix_year.head(10), saturation=.3)
plt.title('The Number of Content in the Last 10 Years', fontsize=21);

# %%
# Extract the year from the date_added column
flix['year_added'] = pd.to_datetime(flix['date_added']).dt.year

# Filter for TV shows
tv_shows = flix[flix['type'] == 'TV Show']

# Count the number of TV shows by year
tv_shows_by_year = tv_shows['year_added'].value_counts().sort_index()

# Plotting the distribution of TV shows by year
plt.figure(figsize=(15, 6))
sns.lineplot(x=tv_shows_by_year.index, y=tv_shows_by_year.values, color='darkblue')
plt.title('Number of TV Shows Released per Year', fontsize =21)
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %%
#INSIGHTS :- Based on above data obtained, sudden raise in trend from 2015 onwards.

# %%
# Extract the year from the date_added column
flix['month_added'] = pd.to_datetime(flix['date_added']).dt.month

# Filter for TV shows
tv_shows = flix[flix['type'] == 'TV Show']

# Count the number of TV shows by year
tv_shows_by_year = tv_shows['month_added'].value_counts().sort_index()

# Plotting the distribution of TV shows by year
plt.figure(figsize=(15, 6))
sns.lineplot(x=tv_shows_by_year.index, y=tv_shows_by_year.values, color='darkgreen')
plt.title('Number of TV Shows Released per Month', fontsize = 21)
plt.xlabel('Month')
plt.ylabel('Count')
plt.show()

# %%
#INSIGHTS :- Based on above data obtained, sudden raise in trend in the month of july and december.

# %%
# Filter for recent years (e.g., 2018 onwards)
recent_years = flix[flix['release_year'] >= 2018]

# Count the number of TV shows and movies in each year
content_counts = recent_years['type'].value_counts()

# Plotting the focus of Netflix on TV shows versus movies
plt.figure(figsize=(8, 6))
plt.bar(content_counts.index, content_counts.values, color=['darkblue', 'darkorange'])
plt.title('Focus of Netflix on TV Shows vs Movies (Recent Years Overall)', fontsize = 15)
plt.xlabel('Content Type')
plt.ylabel('Count')
plt.show()

# %%
# Filter for recent years (e.g., 2018 onwards)
recent_years = flix[flix['release_year'] >= 2018]

# Group by year and content type, and count the number of occurrences
yearly_counts = recent_years.groupby(['release_year', 'type']).size().unstack()

# Plotting the year-wise focus of Netflix on TV shows versus movies
fig, ax = plt.subplots(figsize=(15, 6))
yearly_counts.plot(kind='bar', stacked=True, ax = ax)
plt.title('Focus of Netflix on TV Shows vs Movies (Yearwise)', fontsize = 21)
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend(title='Content Type')
plt.show()

# %%
#INSIGHTS :- Based on above data obtained, It is seen that in 2021 contents from movies and tv shows are almost same.
#And also it is same in recent years.

# %%
# Filter the data where cast_NA is not equal to flix['cast'] and director_NA is not equal to flix['director']
filtered_data = flix[(flix['cast'] != 'cast_NA') & (flix['director'] != 'director_NA')]

# Extracting the actors and directors columns
actors = filtered_data['cast']
directors = filtered_data['director']

# Counting the occurrences of actors and directors for each content type
actor_counts = actors.value_counts()
director_counts = directors.value_counts()

# Plotting the overall top 10 actors
plt.figure(figsize=(14, 6))
actor_counts.head(10).plot(kind='bar', color='purple', alpha=0.7)
plt.title('Overall Top 10 Actors', fontsize = 21)
plt.xlabel('Actor')
plt.ylabel('Count')
plt.show()

# Plotting the overall top 10 directors
plt.figure(figsize=(14, 6))
director_counts.head(10).plot(kind='bar', color='blue', alpha=0.7)
plt.title('Overall Top 10 Directors', fontsize = 21)
plt.xlabel('Director')
plt.ylabel('Count')
plt.show()

# %%
# Filter the data where cast_NA is not equal to flix['cast']
filtered_data = flix[(flix['cast'] != 'cast_NA')]

# Extracting the actors columns
actors = filtered_data['cast']


# Counting the occurrences of actors and directors for each content type
actor_counts_tv = actors[flix['type'] == 'TV Show'].value_counts()
actor_counts_movie = actors[flix['type'] == 'Movie'].value_counts()

# Plotting the top 10 actors in TV shows
plt.figure(figsize=(14, 6))
actor_counts_tv.head(10).plot(kind='bar', color='blue', alpha=0.7)
plt.title('Top 10 Actors in TV Shows', fontsize = 21)
plt.xlabel('Actor')
plt.ylabel('Count')
plt.show()

# Plotting the top 10 actors in movies
plt.figure(figsize=(14, 6))
actor_counts_movie.head(10).plot(kind='bar', color='green', alpha=0.7)
plt.title('Top 10 Actors in Movies', fontsize = 21)
plt.xlabel('Actor')
plt.ylabel('Count')
plt.show()

# %%
# Filter the data where director_NA is not equal to flix['director']
filtered_data = flix[flix['director'] != 'director_NA']

# Extracting the directors columns
directors = filtered_data['director']

# Counting the occurrences of directors for each content type
director_counts_tv = directors[flix['type'] == 'TV Show'].value_counts()
director_counts_movie = directors[flix['type'] == 'Movie'].value_counts()

# Plotting the top 10 directors in TV shows
plt.figure(figsize=(14, 6))
director_counts_tv.head(10).plot(kind='bar', color='red', alpha=0.7)
plt.title('Top 10 Directors in TV Shows', fontsize = 21)
plt.xlabel('Director')
plt.ylabel('Count')
plt.show()

# Plotting the top 10 directors in movies
plt.figure(figsize=(14, 6))
director_counts_movie.head(10).plot(kind='bar', color='orange', alpha=0.7)
plt.title('Top 10 Directors in Movies', fontsize = 21)
plt.xlabel('Director')
plt.ylabel('Count')
plt.show()

# %%
# Percentage distribution of content types in each country
country_content_distribution = flix.groupby('country')['type'].value_counts(normalize=True).mul(100).unstack().fillna(0)

# Plotting the percentage distribution of content types in each country
fig, ax = plt.subplots(figsize=(20, 6))
country_content_distribution.plot(kind='bar', stacked=True, ax=ax)
ax.set_title('Percentage Distribution of Content Types in Each Country', fontsize = 25)
ax.set_xlabel('Country')
ax.set_ylabel('Percentage')
ax.legend(title='Content Type')
ax.set_xticklabels(country_content_distribution.index, rotation=90)
plt.show()

# %%
#Insights & Recommendations :- Based on the analysis of the given dataset, here are some insights and recommendations:

# 1. Top 10 Content Producing Countries: The analysis of content production by country reveals the top 10 countries that 
#    contribute the most to the content available on Netflix. This information can be useful for content acquisition
#    strategies and targeting specific regions for content creation and localization.

# 2. Distribution of Content Types: The analysis of content types (TV shows vs. movies) provides insights into the overall
#    composition of the dataset. It indicates whether Netflix focuses more on TV shows or movies. This information can guide
#    decisions related to content acquisition, production, and marketing efforts.

# 3. Trends in Movies Released per Year: The analysis of the number of movies released per year over the last 20-30 years
#    helps identify trends and patterns. It provides insights into the growth and popularity of movies on Netflix over time.
#    This information can be used to understand audience preferences, plan content release strategies, and identify 
#    potential opportunities for partnerships or collaborations.

# 4. Best Time to Launch a TV Show: By analyzing the distribution of TV shows by month, it is possible to identify the
#    months with higher or lower numbers of TV show releases. This information can help determine the best time to launch
#    a TV show to maximize viewership and engagement. Factors such as seasonality, competition, and audience behavior can
#    be considered when planning TV show releases.

# 5. Analysis of Actors/Directors: Analyzing the top actors and directors in TV shows and movies provides insights into the
#    talent pool associated with different types of content. This information can be useful for casting decisions,
#    identifying popular and influential industry professionals, and understanding audience preferences.

# 6. Content Availability in Different Countries: The analysis of content availability in different countries helps
#    understand the diversity and distribution of content across regions. This information can guide content licensing and
#    distribution strategies, localization efforts, and expansion plans into new markets.

# Recommendations :-

# ---> Explore partnerships or collaborations with content producers and professionals from the top countries to enhance
#      the content library and have a regional preferences also.

# ---> Monitor and analyze trends in the number of movies released per year to identify potential opportunities for 
#      acquiring or producing popular and in-demand content.

# ---> Consider the seasonality and audience preferences when planning the launch of TV shows to optimize viewership and
#      engagement.

# ---> Foster relationships with top actors and directors to collaborate on future projects and leverage their popularity
#      and influence.

# ---> Continuously assess and expand the availability of content in different countries, taking into account cultural
#      nuances and preferences.
